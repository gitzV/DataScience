# %% [markdown]
# <a href="https://colab.research.google.com/github/gitzV/DataScience/blob/main/tds_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
np.random.seed(42) 
M4 = np.random.randn(10,5)
M4
# Out:
# array([[ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986, -0.23415337],
#        [-0.23413696,  1.57921282,  0.76743473, -0.46947439,  0.54256004],
#        [-0.46341769, -0.46572975,  0.24196227, -1.91328024, -1.72491783],
#        [-0.56228753, -1.01283112,  0.31424733, -0.90802408, -1.4123037 ],
#        [ 1.46564877, -0.2257763 ,  0.0675282 , -1.42474819, -0.54438272],
#        [ 0.11092259, -1.15099358,  0.37569802, -0.60063869, -0.29169375],
#        [-0.60170661,  1.85227818, -0.01349722, -1.05771093,  0.82254491],
#        [-1.22084365,  0.2088636 , -1.95967012, -1.32818605,  0.19686124],
#        [ 0.73846658,  0.17136828, -0.11564828, -0.3011037 , -1.47852199],
#        [-0.71984421, -0.46063877,  1.05712223,  0.34361829, -1.76304016]])

# %%
df = pd.DataFrame(M4)
df
# Out:
#           0         1         2         3         4
# 0  0.496714 -0.138264  0.647689  1.523030 -0.234153
# 1 -0.234137  1.579213  0.767435 -0.469474  0.542560
# 2 -0.463418 -0.465730  0.241962 -1.913280 -1.724918
# 3 -0.562288 -1.012831  0.314247 -0.908024 -1.412304
# 4  1.465649 -0.225776  0.067528 -1.424748 -0.544383
# 5  0.110923 -1.150994  0.375698 -0.600639 -0.291694
# 6 -0.601707  1.852278 -0.013497 -1.057711  0.822545
# 7 -1.220844  0.208864 -1.959670 -1.328186  0.196861
# 8  0.738467  0.171368 -0.115648 -0.301104 -1.478522
# 9 -0.719844 -0.460639  1.057122  0.343618 -1.763040

# %%
# re-assign 
df.columns = ["col1", "col2", "col3", "col4", "col5"]

# show 
df
# Out:
#        col1      col2      col3      col4      col5
# 0  0.496714 -0.138264  0.647689  1.523030 -0.234153
# 1 -0.234137  1.579213  0.767435 -0.469474  0.542560
# 2 -0.463418 -0.465730  0.241962 -1.913280 -1.724918
# 3 -0.562288 -1.012831  0.314247 -0.908024 -1.412304
# 4  1.465649 -0.225776  0.067528 -1.424748 -0.544383
# 5  0.110923 -1.150994  0.375698 -0.600639 -0.291694
# 6 -0.601707  1.852278 -0.013497 -1.057711  0.822545
# 7 -1.220844  0.208864 -1.959670 -1.328186  0.196861
# 8  0.738467  0.171368 -0.115648 -0.301104 -1.478522
# 9 -0.719844 -0.460639  1.057122  0.343618 -1.763040

# %%
col3 = df["col3"]  # bracket notation
# col3 = df.col3 
col3
# Out:
# 0    0.647689
# 1    0.767435
# 2    0.241962
# 3    0.314247
# 4    0.067528
# 5    0.375698
# 6   -0.013497
# 7   -1.959670
# 8   -0.115648
# 9    1.057122
# Name: col3, dtype: float64

# %%
type(col3)
# Out:
# pandas.core.series.Series

# %%
col3.shape
# Out:
# (10,)

# %%
col3.describe()
# Out:
# count    10.000000
# mean      0.138287
# std       0.822706
# min      -1.959670
# 25%       0.006759
# 50%       0.278105
# 75%       0.579691
# max       1.057122
# Name: col3, dtype: float64

# %%
df_subset = df[["col1","col2"]] # double square brackets
df_subset
# Out:
#        col1      col2
# 0  0.496714 -0.138264
# 1 -0.234137  1.579213
# 2 -0.463418 -0.465730
# 3 -0.562288 -1.012831
# 4  1.465649 -0.225776
# 5  0.110923 -1.150994
# 6 -0.601707  1.852278
# 7 -1.220844  0.208864
# 8  0.738467  0.171368
# 9 -0.719844 -0.460639

# %%
df_subset = df[["col3","col1"]] # double square brackets
df_subset
# Out:
#        col3      col1
# 0  0.647689  0.496714
# 1  0.767435 -0.234137
# 2  0.241962 -0.463418
# 3  0.314247 -0.562288
# 4  0.067528  1.465649
# 5  0.375698  0.110923
# 6 -0.013497 -0.601707
# 7 -1.959670 -1.220844
# 8 -0.115648  0.738467
# 9  1.057122 -0.719844

# %%
# come up with some data
M5 = np.array([["no","factor1",0],
               ["yes","factor2",2], 
               ["no","factor3",0], 
               ["no","factor4",2],
               ["yes","factor1", 1], 
               ["no","factor2",3],
               ["yes","factor5",3],
               ["no","factor1",0],
               ["yes","factor5",3],
               ["yes","factor1",2],
               ["yes","factor5",1],
               ["no","factor1",2],
               ["no","factor2",0],
               ["yes","factor1",1],
               ["no","factor3",2]
              ])

# create a dataframe with columns
df2 = pd.DataFrame(M5, columns=["Request","Factor","Impact"])
df2["Impact"] = df2["Impact"].astype(int)
df2
# Out:
#    Request   Factor  Impact
# 0       no  factor1       0
# 1      yes  factor2       2
# 2       no  factor3       0
# 3       no  factor4       2
# 4      yes  factor1       1
# 5       no  factor2       3
# 6      yes  factor5       3
# 7       no  factor1       0
# 8      yes  factor5       3
# 9      yes  factor1       2
# 10     yes  factor5       1
# 11      no  factor1       2
# 12      no  factor2       0
# 13     yes  factor1       1
# 14      no  factor3       2

# %%
np.random.seed() # This will fix the random number generation

# create random uniform array of values with compatible shape
cs = np.random.uniform(low=-1, 
                       high=1, 
                       size=(M5.shape[0])) # create a random array 
print(cs.shape)

# Assign array to dataframe
df2["kll_index"] = cs 
display(df2)
# Out:
# (15,)
#    Request   Factor  Impact  kll_index
# 0       no  factor1       0   0.393564
# 1      yes  factor2       2  -0.625847
# 2       no  factor3       0   0.447237
# 3       no  factor4       2  -0.011968
# 4      yes  factor1       1   0.113677
# 5       no  factor2       3  -0.577427
# 6      yes  factor5       3   0.730914
# 7       no  factor1       0   0.783554
# 8      yes  factor5       3   0.101299
# 9      yes  factor1       2   0.208123
# 10     yes  factor5       1  -0.369928
# 11      no  factor1       2  -0.371410
# 12      no  factor2       0  -0.007102
# 13     yes  factor1       1   0.328575
# 14      no  factor3       2  -0.696372

# %%
condition = df2['Request'] == 'no'
condition
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# Name: Request, dtype: bool

# %%
condition1 = df2["Impact"] >= 2  
condition2 = df2["kll_index"] < 0 
condition3 = df2["Factor"] == "factor1"
df2_subset = df2[(condition1|condition2)&condition3]
df2_subset
# Out:
#    Request   Factor  Impact  kll_index
# 9      yes  factor1       2   0.208123
# 11      no  factor1       2  -0.371410

# %%
# suppose we have this mapping 
mapping = {"factor1":"NA", "factor2":"MX","factor3":"LX","factor4":"TY","factor5":"PSOX"}

# apply the mapping to the Service_type column and create a new one  
df2["EDX"] = df2["Factor"].apply(lambda x: mapping.get(x,"Not Found")) 

# display result 
df2
# Out:
#    Request   Factor  Impact  kll_index   EDX
# 0       no  factor1       0   0.393564    NA
# 1      yes  factor2       2  -0.625847    MX
# 2       no  factor3       0   0.447237    LX
# 3       no  factor4       2  -0.011968    TY
# 4      yes  factor1       1   0.113677    NA
# 5       no  factor2       3  -0.577427    MX
# 6      yes  factor5       3   0.730914  PSOX
# 7       no  factor1       0   0.783554    NA
# 8      yes  factor5       3   0.101299  PSOX
# 9      yes  factor1       2   0.208123    NA
# 10     yes  factor5       1  -0.369928  PSOX
# 11      no  factor1       2  -0.371410    NA
# 12      no  factor2       0  -0.007102    MX
# 13     yes  factor1       1   0.328575    NA
# 14      no  factor3       2  -0.696372    LX

# %%
condition = df2["Factor"] == "factor1"
df2.loc[condition, "Request"] = "no" 
df2
# Out:
#    Request   Factor  Impact  kll_index   EDX
# 0       no  factor1       0   0.393564    NA
# 1      yes  factor2       2  -0.625847    MX
# 2       no  factor3       0   0.447237    LX
# 3       no  factor4       2  -0.011968    TY
# 4       no  factor1       1   0.113677    NA
# 5       no  factor2       3  -0.577427    MX
# 6      yes  factor5       3   0.730914  PSOX
# 7       no  factor1       0   0.783554    NA
# 8      yes  factor5       3   0.101299  PSOX
# 9       no  factor1       2   0.208123    NA
# 10     yes  factor5       1  -0.369928  PSOX
# 11      no  factor1       2  -0.371410    NA
# 12      no  factor2       0  -0.007102    MX
# 13      no  factor1       1   0.328575    NA
# 14      no  factor3       2  -0.696372    LX

# %%
df2.sort_values(by=["kll_index"], 
                ascending=True, 
                inplace=True) 
df2
# Out:
#    Request   Factor  Impact  kll_index   EDX
# 14      no  factor3       2  -0.696372    LX
# 1      yes  factor2       2  -0.625847    MX
# 5       no  factor2       3  -0.577427    MX
# 11      no  factor1       2  -0.371410    NA
# 10     yes  factor5       1  -0.369928  PSOX
# 3       no  factor4       2  -0.011968    TY
# 12      no  factor2       0  -0.007102    MX
# 8      yes  factor5       3   0.101299  PSOX
# 4       no  factor1       1   0.113677    NA
# 9       no  factor1       2   0.208123    NA
# 13      no  factor1       1   0.328575    NA
# 0       no  factor1       0   0.393564    NA
# 2       no  factor3       0   0.447237    LX
# 6      yes  factor5       3   0.730914  PSOX
# 7       no  factor1       0   0.783554    NA

# %%
df2.reset_index(inplace=True)
df2
# Out:
#     index Request   Factor  Impact  kll_index   EDX
# 0      14      no  factor3       2  -0.696372    LX
# 1       1     yes  factor2       2  -0.625847    MX
# 2       5      no  factor2       3  -0.577427    MX
# 3      11      no  factor1       2  -0.371410    NA
# 4      10     yes  factor5       1  -0.369928  PSOX
# 5       3      no  factor4       2  -0.011968    TY
# 6      12      no  factor2       0  -0.007102    MX
# 7       8     yes  factor5       3   0.101299  PSOX
# 8       4      no  factor1       1   0.113677    NA
# 9       9      no  factor1       2   0.208123    NA
# 10     13      no  factor1       1   0.328575    NA
# 11      0      no  factor1       0   0.393564    NA
# 12      2      no  factor3       0   0.447237    LX
# 13      6     yes  factor5       3   0.730914  PSOX
# 14      7      no  factor1       0   0.783554    NA

# %%
# specify figure to plot on 
plt.figure(figsize=(15,10)) 

# Obtain x and y arrays
x = df2["Impact"] 
y = df2["kll_index"]

# plot the scatterplot  
plt.scatter(x,y, color="blue", marker="*") 

# add title and labels  
plt.title("Consumption index vs Impact") 
plt.xlabel("Impact") 
plt.ylabel("Consumption_index")
# Out:
# Text(0, 0.5, 'Consumption_index')

# %%
df2.drop(columns=["index"], inplace=True)
df2
# Out:
#    Request   Factor  Impact  kll_index   EDX
# 0       no  factor3       2  -0.696372    LX
# 1      yes  factor2       2  -0.625847    MX
# 2       no  factor2       3  -0.577427    MX
# 3       no  factor1       2  -0.371410    NA
# 4      yes  factor5       1  -0.369928  PSOX
# 5       no  factor4       2  -0.011968    TY
# 6       no  factor2       0  -0.007102    MX
# 7      yes  factor5       3   0.101299  PSOX
# 8       no  factor1       1   0.113677    NA
# 9       no  factor1       2   0.208123    NA
# 10      no  factor1       1   0.328575    NA
# 11      no  factor1       0   0.393564    NA
# 12      no  factor3       0   0.447237    LX
# 13     yes  factor5       3   0.730914  PSOX
# 14      no  factor1       0   0.783554    NA

# %%
df_agg = df2.groupby("EDX").sum().reset_index()
df_agg
# Out:
#     EDX  Impact  kll_index
# 0    LX       2  -0.249135
# 1    MX       5  -1.210376
# 2    NA       6   1.456083
# 3  PSOX       7   0.462286
# 4    TY       2  -0.011968

# %%
# specify figure to plot on 
plt.figure(figsize=(10,5)) 

# Obtain x and y arrays
x = df2["Impact"] 
y = df2["kll_index"]

# plot the scatterplot  
plt.scatter(x,y, color="blue", marker=".") 

# add title and labels  
plt.title("Consumption index vs Impact") 
plt.xlabel("Impact") 
plt.ylabel("Consumption_index")
# Out:
# Text(0, 0.5, 'Consumption_index')

# %%
# create a correlated variable
df2["y"] = df2["kll_index"].apply(lambda x: np.exp(x)*2 if np.random.uniform(-1,1) < 0 else np.exp(x)/2)

# specify figure to plot on 
plt.figure(figsize=(15,10)) 

# Obtain x and y arrays
x = df2["kll_index"] 
y = df2["y"]

# plot the scatterplot  
plt.scatter(x,y, color="blue", marker="*") 

# add title and labels  
plt.title("Consumption index vs target scatterplot") 
plt.xlabel("Consumption Index") 
plt.ylabel("Target")
# Out:
# Text(0, 0.5, 'Target')

# %%
# create a correlated variable
df2["y"] = df2["kll_index"].apply(lambda x: np.exp(x)*2 if np.random.uniform(-1,1) < 0 else np.exp(x)/2)

# specify figure to plot on 
plt.figure(figsize=(15,10)) 

# Obtain x and y arrays
x = df2["kll_index"] 
y = df2["y"]

# plot the scatterplot  
plt.scatter(x,y, color="blue", marker="*") 

# add title and labels  
plt.title("Consumption index vs target scatterplot") 
plt.xlabel("Consumption Index") 
plt.ylabel("Target")
# Out:
# Text(0, 0.5, 'Target')

# %%
# some new data 
df2["y2"] = df2["kll_index"].apply(lambda x: np.exp(x)*2 if np.random.uniform(-0.5,2) < 0 else np.exp(x)/2)

# specify figure to plot on 
plt.figure(figsize=(15,10)) 

# Obtain x and y arrays
x = df2["kll_index"] 
y1 = df2["y"]
y2 = df2["y2"]

# plot the scatterplot  
plt.plot(x,y1, color="red", marker="*") 
plt.plot(x,y2, '--o', color="blue", marker="o") 

# add title and labels  
plt.title("Consumption index vs target scatterplot") 
plt.xlabel("Consumption Index") 
plt.ylabel("Target")
# Out:
# Text(0, 0.5, 'Target')

# %%
plt.figure() 
ax = df_agg.plot.bar(x='EDX', 
                     y='Impact', 
                     rot=0, 
                     figsize=(15,10))
plt.title("Barplot") 
plt.xlabel("EDX") 
plt.ylabel("Counts")
plt.show()
